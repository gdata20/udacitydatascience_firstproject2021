# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

import seaborn as sns
# %matplotlib inline

# %%
boston_listings = pd.read_csv('boston_listings.csv')
seattle_listings = pd.read_csv('seattle_listings.csv')

# %%
boston_listings.head()
# Out:
#       id  ... reviews_per_month
# 0   3781  ...              0.29
# 1   5506  ...              0.90
# 2   6695  ...              1.37
# 3  10730  ...              0.41
# 4  10813  ...              0.18
#
# [5 rows x 74 columns]

# %% [markdown]
# # Planning
#
# ###(I) Data Understanding
# ###(II) EDA
# ###A. Boston vs Seattle
#
# ###neighbourhood numbers
# ###accommodates in each neighbourhood
# ###average price in each neighbourhood, max/min price
# ### room type, property type
# ### average price
# ### reviews/ ratings
#
# ## (III) Data Cleaning
#
# #(III a) Dealing with missing values
#
# #(III b) Dealing with categorical variables
#
#
# ##(IV) Modelling:
# ###predict price

# %% [markdown]
# # (I)Data Understanding

# %%
boston_listings.describe()
# Out:
#                  id  ...  reviews_per_month
# count  3.043000e+03  ...        2251.000000
# mean   3.045123e+07  ...           2.103292
# std    1.569364e+07  ...           4.044184
# min    3.781000e+03  ...           0.010000
# 25%    1.753528e+07  ...           0.260000
# 50%    3.291541e+07  ...           1.000000
# 75%    4.555273e+07  ...           2.680000
# max    5.095972e+07  ...          76.220000
#
# [8 rows x 40 columns]

# %%
boston_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3043 entries, 0 to 3042
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3043 non-null   int64
#  1   listing_url                                   3043 non-null   object
#  2   scrape_id                                     3043 non-null   int64
#  3   last_scraped                                  3043 non-null   object
#  4   name                                          3043 non-null   object
#  5   description                                   3010 non-null   object
#  6   neighborhood_overview                         2073 non-null   object
#  7   picture_url                                   3043 non-null   object
#  8   host_id                                       3043 non-null   int64
#  9   host_url                                      3043 non-null   object
#  10  host_name                                     3043 non-null   object
#  11  host_since                                    3043 non-null   object
#  12  host_location                                 3041 non-null   object
#  13  host_about                                    2047 non-null   object
#  14  host_response_time                            2342 non-null   object
#  15  host_response_rate                            2342 non-null   object
#  16  host_acceptance_rate                          2359 non-null   object
#  17  host_is_superhost                             3043 non-null   object
#  18  host_thumbnail_url                            3043 non-null   object
#  19  host_picture_url                              3043 non-null   object
#  20  host_neighbourhood                            2841 non-null   object
#  21  host_listings_count                           3043 non-null   int64
#  22  host_total_listings_count                     3043 non-null   int64
#  23  host_verifications                            3043 non-null   object
#  24  host_has_profile_pic                          3043 non-null   object
#  25  host_identity_verified                        3043 non-null   object
#  26  neighbourhood                                 2073 non-null   object
#  27  neighbourhood_cleansed                        3043 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      3043 non-null   float64
#  30  longitude                                     3043 non-null   float64
#  31  property_type                                 3043 non-null   object
#  32  room_type                                     3043 non-null   object
#  33  accommodates                                  3043 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                3040 non-null   object
#  36  bedrooms                                      2650 non-null   float64
#  37  beds                                          2966 non-null   float64
#  38  amenities                                     3043 non-null   object
#  39  price                                         3043 non-null   object
#  40  minimum_nights                                3043 non-null   int64
#  41  maximum_nights                                3043 non-null   int64
#  42  minimum_minimum_nights                        3043 non-null   int64
#  43  maximum_minimum_nights                        3043 non-null   int64
#  44  minimum_maximum_nights                        3043 non-null   int64
#  45  maximum_maximum_nights                        3043 non-null   int64
#  46  minimum_nights_avg_ntm                        3043 non-null   float64
#  47  maximum_nights_avg_ntm                        3043 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              3043 non-null   object
#  50  availability_30                               3043 non-null   int64
#  51  availability_60                               3043 non-null   int64
#  52  availability_90                               3043 non-null   int64
#  53  availability_365                              3043 non-null   int64
#  54  calendar_last_scraped                         3043 non-null   object
#  55  number_of_reviews                             3043 non-null   int64
#  56  number_of_reviews_ltm                         3043 non-null   int64
#  57  number_of_reviews_l30d                        3043 non-null   int64
#  58  first_review                                  2251 non-null   object
#  59  last_review                                   2251 non-null   object
#  60  review_scores_rating                          2251 non-null   float64
#  61  review_scores_accuracy                        2237 non-null   float64
#  62  review_scores_cleanliness                     2238 non-null   float64
#  63  review_scores_checkin                         2236 non-null   float64
#  64  review_scores_communication                   2238 non-null   float64
#  65  review_scores_location                        2236 non-null   float64
#  66  review_scores_value                           2236 non-null   float64
#  67  license                                       1691 non-null   object
#  68  instant_bookable                              3043 non-null   object
#  69  calculated_host_listings_count                3043 non-null   int64
#  70  calculated_host_listings_count_entire_homes   3043 non-null   int64
#  71  calculated_host_listings_count_private_rooms  3043 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   3043 non-null   int64
#  73  reviews_per_month                             2251 non-null   float64
# dtypes: float64(17), int64(23), object(34)
# memory usage: 1.7+ MB

# %%
boston_listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# # (II) EDA
# A .Boston/Seattle EDA

# %%
fig, ax = plt.subplots(figsize=(6 , 8))
ax.bar(0,boston_listings.shape[0],width=0.2)
ax.bar(0.2,seattle_listings.shape[0],width=0.2)

plt.title('Number of accomodation in Boston and Seattle')

plt.legend(labels=["boston","seattle"])

# %%
#neighbourhood,neighbourhood_group_cleansed,neighbourhood_cleansed
boston_listings['neighbourhood_cleansed'].value_counts().plot(kind='bar')
plt.title('Neighbourhood of the accomodation in Boston')
# Out:
# Text(0.5, 1.0, 'Neighbourhood of the accomodation in Boston')

# %%
plt.figure(figsize=(18 , 8))
seattle_listings['neighbourhood_cleansed'].value_counts().plot(kind='bar',color='green')
plt.title('Neighbourhood of the accomodation in Seattle')
# Out:
# Text(0.5, 1.0, 'Neighbourhood of the accomodation in Seattle')

# %%
fig, ax =plt.subplots(1,2, sharex=True, figsize=(10,5))

boston_listings['accommodates'].value_counts().plot(kind='bar',ax=ax[0])
seattle_listings['accommodates'].value_counts().plot(kind='bar',color='green',ax=ax[1])
ax[0].set_title('Number of accommodates type in Boston')
ax[1].set_title('Number of accommodates type in Seattle')
# Out:
# Text(0.5, 1.0, 'Number of accommodates type in Seattle')

# %%
fig, ax =plt.subplots(1,2, sharex=True, figsize=(10,5))

boston_listings['room_type'].value_counts().plot(kind='bar',ax=ax[0])
seattle_listings['room_type'].value_counts().plot(kind='bar',color='green',ax=ax[1])
ax[0].set_title('Room Type in Boston')
ax[1].set_title('Room Type in Seattle')
# Out:
# Text(0.5, 1.0, 'Room Type in Seattle')

# %%
fig, ax =plt.subplots(1,2, sharex=True, figsize=(20,5))

boston_listings['property_type'].value_counts().plot(kind='bar',ax=ax[0])
seattle_listings['property_type'].value_counts().plot(kind='bar',color='green',ax=ax[1])
ax[0].set_title('property type in Boston')
ax[1].set_title('property type in Seattle')
# Out:
# Text(0.5, 1.0, 'property type in Seattle')

# %% [markdown]
# Price understanding

# %%
boston_listings['price'].value_counts()
# Out:
# $100.00    72
# $120.00    58
# $50.00     57
# $200.00    55
# $150.00    49
#            ..
# $284.00     1
# $424.00     1
# $470.00     1
# $558.00     1
# $336.00     1
# Name: price, Length: 460, dtype: int64

# %%
#change price to numeric
boston_listings['price']=boston_listings['price'].str[1:].str[:-3]
boston_listings['price']=boston_listings['price'].str.replace(',', '')
boston_listings['price']=pd.to_numeric(boston_listings['price'])
boston_listings['price']
# Out:
# 0       125
# 1       145
# 2       169
# 3        76
# 4       106
#        ...
# 3038    269
# 3039    115
# 3040    532
# 3041    193
# 3042    195
# Name: price, Length: 3043, dtype: int64

# %%
#change price to numeric
seattle_listings['price']=seattle_listings['price'].str[1:].str[:-3]
seattle_listings['price']=seattle_listings['price'].str.replace(',', '')
seattle_listings['price']=pd.to_numeric(seattle_listings['price'])
seattle_listings['price']
# Out:
# 0       475
# 1       102
# 2        75
# 3       165
# 4       125
#        ...
# 4091    315
# 4092    318
# 4093    235
# 4094     84
# 4095    222
# Name: price, Length: 4096, dtype: int64

# %%
boston_listings['price'].max()
# Out:
# 10000

# %%
seattle_listings['price'].max()
# Out:
# 3750

# %%
boston_listings['price'].min()
# Out:
# 0

# %%
seattle_listings['price'].min()
# Out:
# 19

# %%
boston_listings['price'].mean()
# Out:
# 182.78047978968124

# %%
seattle_listings['price'].mean()
# Out:
# 179.37841796875

# %%
fig, ax = plt.subplots(figsize=(28 , 8))
sns.kdeplot(data=boston_listings['price'],
                ax=ax)
sns.kdeplot(data=seattle_listings['price'],
                ax=ax)

plt.title('Price per night of accomodations in Boston and Seattle')

plt.legend(labels=["boston","seattle"])
ax.set(xlim=(0, 2000))
# Out:
# [(0.0, 2000.0)]

# %%
boston_listings[boston_listings['price']<10]
# Out:
#             id  ... reviews_per_month
# 2010  42065556  ...              2.47
# 2011  42065558  ...              7.58
#
# [2 rows x 74 columns]

# %%
seattle_listings[seattle_listings['price']<10]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, scrape_id, last_scraped, name, description, neighborhood_overview, picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, license, instant_bookable, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, reviews_per_month]
# Index: []

# %%
# the price of the room is not 0 according to the url
boston_listings.iloc[2010,39]=778
boston_listings.iloc[2011,39]=350

# %%
boston_listings.iloc[2010,39]
# Out:
# 778

# %%
boston_listings.iloc[2011,39]
# Out:
# 350

# %% [markdown]
# # (II) EDA
# B.Ratings analysis

# %%
boston_listings['review_scores_rating'].isnull().sum()
# Out:
# 792

# %%
seattle_listings['review_scores_rating'].isnull().sum()
# Out:
# 763

# %%
fig, ax = plt.subplots(figsize=(6 , 8))
ax.bar(0,boston_listings['review_scores_rating'].mean(),width=0.2)
ax.bar(0.2,seattle_listings['review_scores_rating'].mean(),width=0.2)

plt.title('Mean of review score in Boston and Seattle')

plt.legend(labels=["boston","seattle"])

# %%
boston_reviews_mean =boston_listings['review_scores_rating'].mean()

# %%
seattle_reviews_mean = seattle_listings['review_scores_rating'].mean()

# %%
#fill null ratings with mean
boston_listings['review_scores_rating'].fillna(boston_reviews_mean)
# Out:
# 0       4.950000
# 1       4.770000
# 2       4.790000
# 3       4.780000
# 4       5.000000
#           ...
# 3038    4.649325
# 3039    4.649325
# 3040    4.649325
# 3041    4.649325
# 3042    4.649325
# Name: review_scores_rating, Length: 3043, dtype: float64

# %%
#fill null ratings with mean
seattle_listings['review_scores_rating'].fillna(seattle_reviews_mean)
# Out:
# 0       5.00000
# 1       4.60000
# 2       4.66000
# 3       4.96000
# 4       4.98000
#          ...
# 4091    4.74565
# 4092    4.74565
# 4093    4.74565
# 4094    4.74565
# 4095    4.74565
# Name: review_scores_rating, Length: 4096, dtype: float64

# %%
fig, ax =plt.subplots(1,2, sharex=True, figsize=(10,5))
sns.violinplot(data=boston_listings['review_scores_rating'],
                ax=ax[0])
sns.violinplot(data=seattle_listings['review_scores_rating'],
                ax=ax[1])

ax[0].set_title('review scores rating in Boston')
ax[1].set_title('review scores rating in Boston Seattle')
# Out:
# Text(0.5, 1.0, 'review scores rating in Boston Seattle')

# %% [markdown]
# ### Exploring relationship between data

# %%
fig, ax =plt.subplots(1,2, sharex=True, figsize=(10,5))

sns.scatterplot(data=boston_listings, y='price', x='review_scores_rating',
                ax=ax[0])
sns.scatterplot(data=seattle_listings, y='price', x='review_scores_rating',
                ax=ax[1])

ax[0].set_title('Relationship between price and ratings in Boston')
ax[1].set_title('Relationship between price and ratings in Seattle')
# Out:
# Text(0.5, 1.0, 'Relationship between price and ratings in Seattle')

# %%
#remove outliers of price
boston_listings= boston_listings[boston_listings['price']<2000]
seattle_listings= seattle_listings[seattle_listings['price']<2000]

# %%
numeric_boston = boston_listings.select_dtypes(include=np.number)
numeric_boston = boston_listings.drop(['id','scrape_id','host_id'],axis=1)


numeric_seattle = seattle_listings.select_dtypes(include=np.number)
numeric_seattle = seattle_listings.drop(['id','scrape_id','host_id'],axis=1)

# %%
numeric_boston.columns
# Out:
# Index(['listing_url', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
#Correlation of varaibles of Boston
fig, ax = plt.subplots(figsize=(30,30))  
corr = numeric_boston.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
#Correlation of varaibles of Seattle
fig, ax = plt.subplots(figsize=(30,30))  
corr = numeric_seattle.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# ## B.Reviews

# %% [markdown]
# # (III)Data Cleaning

# %% [markdown]
# ### (III a) Dealing with missing values

# %%
boston_listings_clean=boston_listings.copy()
seattle_listings_clean=seattle_listings.copy()

# %%
boston_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3037 entries, 0 to 3042
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3037 non-null   int64
#  1   listing_url                                   3037 non-null   object
#  2   scrape_id                                     3037 non-null   int64
#  3   last_scraped                                  3037 non-null   object
#  4   name                                          3037 non-null   object
#  5   description                                   3004 non-null   object
#  6   neighborhood_overview                         2068 non-null   object
#  7   picture_url                                   3037 non-null   object
#  8   host_id                                       3037 non-null   int64
#  9   host_url                                      3037 non-null   object
#  10  host_name                                     3037 non-null   object
#  11  host_since                                    3037 non-null   object
#  12  host_location                                 3035 non-null   object
#  13  host_about                                    2043 non-null   object
#  14  host_response_time                            2338 non-null   object
#  15  host_response_rate                            2338 non-null   object
#  16  host_acceptance_rate                          2355 non-null   object
#  17  host_is_superhost                             3037 non-null   object
#  18  host_thumbnail_url                            3037 non-null   object
#  19  host_picture_url                              3037 non-null   object
#  20  host_neighbourhood                            2835 non-null   object
#  21  host_listings_count                           3037 non-null   int64
#  22  host_total_listings_count                     3037 non-null   int64
#  23  host_verifications                            3037 non-null   object
#  24  host_has_profile_pic                          3037 non-null   object
#  25  host_identity_verified                        3037 non-null   object
#  26  neighbourhood                                 2068 non-null   object
#  27  neighbourhood_cleansed                        3037 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      3037 non-null   float64
#  30  longitude                                     3037 non-null   float64
#  31  property_type                                 3037 non-null   object
#  32  room_type                                     3037 non-null   object
#  33  accommodates                                  3037 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                3034 non-null   object
#  36  bedrooms                                      2644 non-null   float64
#  37  beds                                          2960 non-null   float64
#  38  amenities                                     3037 non-null   object
#  39  price                                         3037 non-null   int64
#  40  minimum_nights                                3037 non-null   int64
#  41  maximum_nights                                3037 non-null   int64
#  42  minimum_minimum_nights                        3037 non-null   int64
#  43  maximum_minimum_nights                        3037 non-null   int64
#  44  minimum_maximum_nights                        3037 non-null   int64
#  45  maximum_maximum_nights                        3037 non-null   int64
#  46  minimum_nights_avg_ntm                        3037 non-null   float64
#  47  maximum_nights_avg_ntm                        3037 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              3037 non-null   object
#  50  availability_30                               3037 non-null   int64
#  51  availability_60                               3037 non-null   int64
#  52  availability_90                               3037 non-null   int64
#  53  availability_365                              3037 non-null   int64
#  54  calendar_last_scraped                         3037 non-null   object
#  55  number_of_reviews                             3037 non-null   int64
#  56  number_of_reviews_ltm                         3037 non-null   int64
#  57  number_of_reviews_l30d                        3037 non-null   int64
#  58  first_review                                  2247 non-null   object
#  59  last_review                                   2247 non-null   object
#  60  review_scores_rating                          2247 non-null   float64
#  61  review_scores_accuracy                        2233 non-null   float64
#  62  review_scores_cleanliness                     2234 non-null   float64
#  63  review_scores_checkin                         2232 non-null   float64
#  64  review_scores_communication                   2234 non-null   float64
#  65  review_scores_location                        2232 non-null   float64
#  66  review_scores_value                           2232 non-null   float64
#  67  license                                       1688 non-null   object
#  68  instant_bookable                              3037 non-null   object
#  69  calculated_host_listings_count                3037 non-null   int64
#  70  calculated_host_listings_count_entire_homes   3037 non-null   int64
#  71  calculated_host_listings_count_private_rooms  3037 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   3037 non-null   int64
#  73  reviews_per_month                             2247 non-null   float64
# dtypes: float64(17), int64(24), object(33)
# memory usage: 1.7+ MB

# %%
seattle_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4094 entries, 0 to 4095
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4094 non-null   int64
#  1   listing_url                                   4094 non-null   object
#  2   scrape_id                                     4094 non-null   int64
#  3   last_scraped                                  4094 non-null   object
#  4   name                                          4094 non-null   object
#  5   description                                   4085 non-null   object
#  6   neighborhood_overview                         2897 non-null   object
#  7   picture_url                                   4094 non-null   object
#  8   host_id                                       4094 non-null   int64
#  9   host_url                                      4094 non-null   object
#  10  host_name                                     4094 non-null   object
#  11  host_since                                    4094 non-null   object
#  12  host_location                                 4087 non-null   object
#  13  host_about                                    3111 non-null   object
#  14  host_response_time                            3659 non-null   object
#  15  host_response_rate                            3659 non-null   object
#  16  host_acceptance_rate                          3719 non-null   object
#  17  host_is_superhost                             4094 non-null   object
#  18  host_thumbnail_url                            4094 non-null   object
#  19  host_picture_url                              4094 non-null   object
#  20  host_neighbourhood                            3778 non-null   object
#  21  host_listings_count                           4094 non-null   int64
#  22  host_total_listings_count                     4094 non-null   int64
#  23  host_verifications                            4094 non-null   object
#  24  host_has_profile_pic                          4094 non-null   object
#  25  host_identity_verified                        4094 non-null   object
#  26  neighbourhood                                 2897 non-null   object
#  27  neighbourhood_cleansed                        4094 non-null   object
#  28  neighbourhood_group_cleansed                  4094 non-null   object
#  29  latitude                                      4094 non-null   float64
#  30  longitude                                     4094 non-null   float64
#  31  property_type                                 4094 non-null   object
#  32  room_type                                     4094 non-null   object
#  33  accommodates                                  4094 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                4092 non-null   object
#  36  bedrooms                                      3476 non-null   float64
#  37  beds                                          4003 non-null   float64
#  38  amenities                                     4094 non-null   object
#  39  price                                         4094 non-null   int64
#  40  minimum_nights                                4094 non-null   int64
#  41  maximum_nights                                4094 non-null   int64
#  42  minimum_minimum_nights                        4094 non-null   int64
#  43  maximum_minimum_nights                        4094 non-null   int64
#  44  minimum_maximum_nights                        4094 non-null   int64
#  45  maximum_maximum_nights                        4094 non-null   int64
#  46  minimum_nights_avg_ntm                        4094 non-null   float64
#  47  maximum_nights_avg_ntm                        4094 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              4094 non-null   object
#  50  availability_30                               4094 non-null   int64
#  51  availability_60                               4094 non-null   int64
#  52  availability_90                               4094 non-null   int64
#  53  availability_365                              4094 non-null   int64
#  54  calendar_last_scraped                         4094 non-null   object
#  55  number_of_reviews                             4094 non-null   int64
#  56  number_of_reviews_ltm                         4094 non-null   int64
#  57  number_of_reviews_l30d                        4094 non-null   int64
#  58  first_review                                  3333 non-null   object
#  59  last_review                                   3333 non-null   object
#  60  review_scores_rating                          3333 non-null   float64
#  61  review_scores_accuracy                        3328 non-null   float64
#  62  review_scores_cleanliness                     3328 non-null   float64
#  63  review_scores_checkin                         3328 non-null   float64
#  64  review_scores_communication                   3328 non-null   float64
#  65  review_scores_location                        3328 non-null   float64
#  66  review_scores_value                           3328 non-null   float64
#  67  license                                       2977 non-null   object
#  68  instant_bookable                              4094 non-null   object
#  69  calculated_host_listings_count                4094 non-null   int64
#  70  calculated_host_listings_count_entire_homes   4094 non-null   int64
#  71  calculated_host_listings_count_private_rooms  4094 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   4094 non-null   int64
#  73  reviews_per_month                             3333 non-null   float64
# dtypes: float64(16), int64(24), object(34)
# memory usage: 2.3+ MB

# %%
boston_listings_clean = boston_listings_clean.dropna(how='all', axis=1)
seattle_listings_clean = seattle_listings_clean.dropna(how='all', axis=1)

# %%
seattle_listings['neighbourhood_group_cleansed'].value_counts()
# Out:
# Other neighborhoods    783
# Downtown               688
# Capitol Hill           410
# Central Area           306
# West Seattle           269
# Queen Anne             256
# University District    231
# Rainier Valley         228
# Beacon Hill            200
# Ballard                187
# Cascade                127
# Delridge               124
# Northgate               99
# Lake City               68
# Magnolia                66
# Seward Park             31
# Interbay                21
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
seattle_listings['neighbourhood_cleansed'].value_counts()
# Out:
# Belltown               277
# Broadway               252
# University District    231
# Fremont                147
# First Hill             133
#                       ...
# Briarcliff               7
# Windermere               5
# View Ridge               4
# Meadowbrook              4
# Holly Park               2
# Name: neighbourhood_cleansed, Length: 87, dtype: int64

# %%
seattle_listings['bathrooms']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4091   NaN
# 4092   NaN
# 4093   NaN
# 4094   NaN
# 4095   NaN
# Name: bathrooms, Length: 4094, dtype: float64

# %%
boston_listings_clean = boston_listings.drop(['calendar_updated','bathrooms','neighbourhood_group_cleansed'],axis=1)

boston_listings_clean = boston_listings.drop(['calendar_updated','bathrooms','neighbourhood_group_cleansed'],axis=1)

# %%
boston_listings_clean['beds'].value_counts()
# Out:
# 1.0     1722
# 2.0      673
# 3.0      251
# 0.0      103
# 4.0      102
# 5.0       52
# 6.0       24
# 7.0       12
# 9.0        7
# 8.0        6
# 10.0       2
# 12.0       2
# 11.0       2
# 16.0       1
# 18.0       1
# Name: beds, dtype: int64

# %%
boston_listings_clean['beds'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
boston_listings_clean['beds'].notnull().sum()
# Out:
# 2960

# %%
1722/2960
# Out:
# 0.5817567567567568

# %%
boston_listings_clean['beds'].mean()
# Out:
# 1.664864864864865

# %%
#fill null value with mode/mean/0

def fill_null_mode(col):

    mode_boston = boston_listings_clean[col].mode()
    boston_listings_clean[col] = boston_listings_clean[col].fillna(mode_boston[0])
    

    mode_seattle = seattle_listings_clean[col].mode()
    seattle_listings_clean[col] = seattle_listings_clean[col].fillna(mode_seattle[0])
    

def fill_null_mean(col):

    mean_boston = boston_listings_clean[col].mean()
    boston_listings_clean[col] = boston_listings_clean[col].fillna(mean_boston)

    mean_seattle = seattle_listings_clean[col].mean()
    seattle_listings_clean[col]=seattle_listings_clean[col].fillna(mean_seattle)

def fill_null_zero(col):
    boston_listings_clean[col] = boston_listings_clean[col].fillna(0)
    seattle_listings_clean[col] = seattle_listings_clean[col].fillna(0)

# %%
boston_listings_clean['first_review']
# Out:
# 0       2015-10-30
# 1       2011-10-23
# 2       2014-08-12
# 3       2015-03-01
# 4       2019-03-17
#            ...
# 3038           NaN
# 3039           NaN
# 3040           NaN
# 3041           NaN
# 3042           NaN
# Name: first_review, Length: 3037, dtype: object

# %%
boston_listings_clean[boston_listings_clean['first_review'].isnull()==True]
# Out:
#             id  ... reviews_per_month
# 6        13247  ...               NaN
# 7        16384  ...               NaN
# 67     1077105  ...               NaN
# 117    2402963  ...               NaN
# 119    2444202  ...               NaN
# ...        ...  ...               ...
# 3038  50904278  ...               NaN
# 3039  50917545  ...               NaN
# 3040  50937751  ...               NaN
# 3041  50955477  ...               NaN
# 3042  50959720  ...               NaN
#
# [790 rows x 71 columns]

# %%
#get the year for the data column to simplify the handling of date
def date_clean(col):

  boston_listings_clean[col]=boston_listings_clean[col].apply(lambda x:str(x).split("-")[0])
  seattle_listings_clean[col]=seattle_listings_clean[col].apply(lambda x:str(x).split("-")[0])

  boston_listings_clean[col]=pd.to_numeric(boston_listings_clean[col].replace('nan',0))
  seattle_listings_clean[col]=pd.to_numeric(seattle_listings_clean[col].replace('nan',0))

# %%
date_clean('first_review')

date_clean('last_review')

# %%
boston_listings_clean['first_review'].value_counts()
# Out:
# 0       790
# 2019    469
# 2021    443
# 2018    381
# 2017    280
# 2020    252
# 2016    216
# 2015    115
# 2014     50
# 2013     28
# 2012      9
# 2011      2
# 2010      2
# Name: first_review, dtype: int64

# %%
boston_listings_clean['last_review'].value_counts()
# Out:
# 2021    1186
# 0        790
# 2020     410
# 2019     380
# 2018      95
# 2017      85
# 2016      65
# 2015      23
# 2014       2
# 2013       1
# Name: last_review, dtype: int64

# %%
boston_listings_clean['first_review'].isnull().sum()
# Out:
# 0

# %%
boston_listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3037 entries, 0 to 3042
# Data columns (total 71 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3037 non-null   int64
#  1   listing_url                                   3037 non-null   object
#  2   scrape_id                                     3037 non-null   int64
#  3   last_scraped                                  3037 non-null   object
#  4   name                                          3037 non-null   object
#  5   description                                   3004 non-null   object
#  6   neighborhood_overview                         2068 non-null   object
#  7   picture_url                                   3037 non-null   object
#  8   host_id                                       3037 non-null   int64
#  9   host_url                                      3037 non-null   object
#  10  host_name                                     3037 non-null   object
#  11  host_since                                    3037 non-null   object
#  12  host_location                                 3035 non-null   object
#  13  host_about                                    2043 non-null   object
#  14  host_response_time                            2338 non-null   object
#  15  host_response_rate                            2338 non-null   object
#  16  host_acceptance_rate                          2355 non-null   object
#  17  host_is_superhost                             3037 non-null   object
#  18  host_thumbnail_url                            3037 non-null   object
#  19  host_picture_url                              3037 non-null   object
#  20  host_neighbourhood                            2835 non-null   object
#  21  host_listings_count                           3037 non-null   int64
#  22  host_total_listings_count                     3037 non-null   int64
#  23  host_verifications                            3037 non-null   object
#  24  host_has_profile_pic                          3037 non-null   object
#  25  host_identity_verified                        3037 non-null   object
#  26  neighbourhood                                 2068 non-null   object
#  27  neighbourhood_cleansed                        3037 non-null   object
#  28  latitude                                      3037 non-null   float64
#  29  longitude                                     3037 non-null   float64
#  30  property_type                                 3037 non-null   object
#  31  room_type                                     3037 non-null   object
#  32  accommodates                                  3037 non-null   int64
#  33  bathrooms_text                                3034 non-null   object
#  34  bedrooms                                      2644 non-null   float64
#  35  beds                                          2960 non-null   float64
#  36  amenities                                     3037 non-null   object
#  37  price                                         3037 non-null   int64
#  38  minimum_nights                                3037 non-null   int64
#  39  maximum_nights                                3037 non-null   int64
#  40  minimum_minimum_nights                        3037 non-null   int64
#  41  maximum_minimum_nights                        3037 non-null   int64
#  42  minimum_maximum_nights                        3037 non-null   int64
#  43  maximum_maximum_nights                        3037 non-null   int64
#  44  minimum_nights_avg_ntm                        3037 non-null   float64
#  45  maximum_nights_avg_ntm                        3037 non-null   float64
#  46  has_availability                              3037 non-null   object
#  47  availability_30                               3037 non-null   int64
#  48  availability_60                               3037 non-null   int64
#  49  availability_90                               3037 non-null   int64
#  50  availability_365                              3037 non-null   int64
#  51  calendar_last_scraped                         3037 non-null   object
#  52  number_of_reviews                             3037 non-null   int64
#  53  number_of_reviews_ltm                         3037 non-null   int64
#  54  number_of_reviews_l30d                        3037 non-null   int64
#  55  first_review                                  3037 non-null   int64
#  56  last_review                                   3037 non-null   int64
#  57  review_scores_rating                          2247 non-null   float64
#  58  review_scores_accuracy                        2233 non-null   float64
#  59  review_scores_cleanliness                     2234 non-null   float64
#  60  review_scores_checkin                         2232 non-null   float64
#  61  review_scores_communication                   2234 non-null   float64
#  62  review_scores_location                        2232 non-null   float64
#  63  review_scores_value                           2232 non-null   float64
#  64  license                                       1688 non-null   object
#  65  instant_bookable                              3037 non-null   object
#  66  calculated_host_listings_count                3037 non-null   int64
#  67  calculated_host_listings_count_entire_homes   3037 non-null   int64
#  68  calculated_host_listings_count_private_rooms  3037 non-null   int64
#  69  calculated_host_listings_count_shared_rooms   3037 non-null   int64
#  70  reviews_per_month                             2247 non-null   float64
# dtypes: float64(14), int64(26), object(31)
# memory usage: 1.7+ MB

# %%
boston_listings_clean[boston_listings_clean['reviews_per_month'].isnull()]
# Out:
#             id  ... reviews_per_month
# 6        13247  ...               NaN
# 7        16384  ...               NaN
# 67     1077105  ...               NaN
# 117    2402963  ...               NaN
# 119    2444202  ...               NaN
# ...        ...  ...               ...
# 3038  50904278  ...               NaN
# 3039  50917545  ...               NaN
# 3040  50937751  ...               NaN
# 3041  50955477  ...               NaN
# 3042  50959720  ...               NaN
#
# [790 rows x 71 columns]

# %%
#fill null review number per month with 0

fill_null_zero('reviews_per_month')

# %%
review_list = ['review_scores_rating','review_scores_accuracy', 'review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value']

def repalce_wif_mean(df):
  for review in review_list:
    mean = df[review].mean()
    df[review].fillna(mean,inplace=True)

# %%
#fill null review score with mean
repalce_wif_mean(boston_listings_clean)
repalce_wif_mean(seattle_listings_clean)

# %%
boston_listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3037 entries, 0 to 3042
# Data columns (total 71 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3037 non-null   int64
#  1   listing_url                                   3037 non-null   object
#  2   scrape_id                                     3037 non-null   int64
#  3   last_scraped                                  3037 non-null   object
#  4   name                                          3037 non-null   object
#  5   description                                   3004 non-null   object
#  6   neighborhood_overview                         2068 non-null   object
#  7   picture_url                                   3037 non-null   object
#  8   host_id                                       3037 non-null   int64
#  9   host_url                                      3037 non-null   object
#  10  host_name                                     3037 non-null   object
#  11  host_since                                    3037 non-null   object
#  12  host_location                                 3035 non-null   object
#  13  host_about                                    2043 non-null   object
#  14  host_response_time                            2338 non-null   object
#  15  host_response_rate                            2338 non-null   object
#  16  host_acceptance_rate                          2355 non-null   object
#  17  host_is_superhost                             3037 non-null   object
#  18  host_thumbnail_url                            3037 non-null   object
#  19  host_picture_url                              3037 non-null   object
#  20  host_neighbourhood                            2835 non-null   object
#  21  host_listings_count                           3037 non-null   int64
#  22  host_total_listings_count                     3037 non-null   int64
#  23  host_verifications                            3037 non-null   object
#  24  host_has_profile_pic                          3037 non-null   object
#  25  host_identity_verified                        3037 non-null   object
#  26  neighbourhood                                 2068 non-null   object
#  27  neighbourhood_cleansed                        3037 non-null   object
#  28  latitude                                      3037 non-null   float64
#  29  longitude                                     3037 non-null   float64
#  30  property_type                                 3037 non-null   object
#  31  room_type                                     3037 non-null   object
#  32  accommodates                                  3037 non-null   int64
#  33  bathrooms_text                                3034 non-null   object
#  34  bedrooms                                      2644 non-null   float64
#  35  beds                                          2960 non-null   float64
#  36  amenities                                     3037 non-null   object
#  37  price                                         3037 non-null   int64
#  38  minimum_nights                                3037 non-null   int64
#  39  maximum_nights                                3037 non-null   int64
#  40  minimum_minimum_nights                        3037 non-null   int64
#  41  maximum_minimum_nights                        3037 non-null   int64
#  42  minimum_maximum_nights                        3037 non-null   int64
#  43  maximum_maximum_nights                        3037 non-null   int64
#  44  minimum_nights_avg_ntm                        3037 non-null   float64
#  45  maximum_nights_avg_ntm                        3037 non-null   float64
#  46  has_availability                              3037 non-null   object
#  47  availability_30                               3037 non-null   int64
#  48  availability_60                               3037 non-null   int64
#  49  availability_90                               3037 non-null   int64
#  50  availability_365                              3037 non-null   int64
#  51  calendar_last_scraped                         3037 non-null   object
#  52  number_of_reviews                             3037 non-null   int64
#  53  number_of_reviews_ltm                         3037 non-null   int64
#  54  number_of_reviews_l30d                        3037 non-null   int64
#  55  first_review                                  3037 non-null   int64
#  56  last_review                                   3037 non-null   int64
#  57  review_scores_rating                          3037 non-null   float64
#  58  review_scores_accuracy                        3037 non-null   float64
#  59  review_scores_cleanliness                     3037 non-null   float64
#  60  review_scores_checkin                         3037 non-null   float64
#  61  review_scores_communication                   3037 non-null   float64
#  62  review_scores_location                        3037 non-null   float64
#  63  review_scores_value                           3037 non-null   float64
#  64  license                                       1688 non-null   object
#  65  instant_bookable                              3037 non-null   object
#  66  calculated_host_listings_count                3037 non-null   int64
#  67  calculated_host_listings_count_entire_homes   3037 non-null   int64
#  68  calculated_host_listings_count_private_rooms  3037 non-null   int64
#  69  calculated_host_listings_count_shared_rooms   3037 non-null   int64
#  70  reviews_per_month                             3037 non-null   float64
# dtypes: float64(14), int64(26), object(31)
# memory usage: 1.7+ MB

# %%
boston_listings_clean['neighbourhood'].value_counts()
# Out:
# Boston, Massachusetts, United States                                            2000
# Dorchester , Massachusetts, United States                                         13
# East Boston, Massachusetts, United States                                          7
# Dorchester, Massachusetts, United States                                           7
# Charlestown, Massachusetts, United States                                          5
# BOSTON, Massachusetts, United States                                               4
# Jamaica Plain, Massachusetts, United States                                        4
# Brighton, Massachusetts, United States                                             3
# Boston , Massachusetts, United States                                              2
# Dorchester,, Massachusetts, United States                                          2
# Roslindale, Massachusetts, United States                                           2
# Brookline, Massachusetts, United States                                            2
# Dorchster , Massachusetts, United States                                           2
# Jamaica Plain, Boston, Massachusetts, United States                                1
# Milton, Massachusetts, United States                                               1
# Chestnut Hill, Massachusetts, United States                                        1
# 88 Auckland Street, Apt 1, Dorchester, MA 0212, Massachusetts, United States       1
# Hyde Park, Massachusetts, United States                                            1
# Jamaica Plain , Massachusetts, United States                                       1
# Boston (Jamaica Plain), Massachusetts, United States                               1
# Allston, Massachusetts, United States                                              1
# Boston/Charlestown , Massachusetts, United States                                  1
# Hyde Park , Massachusetts, United States                                           1
# Dedham, Massachusetts, United States                                               1
# Somerville, Massachusetts, United States                                           1
# 波士顿, Massachusetts, United States                                                  1
# Boston, Allston, Ma, United States                                                 1
# Roxbury Crossing, Massachusetts, United States                                     1
# Name: neighbourhood, dtype: int64

# %%
seattle_listings_clean['neighbourhood'].value_counts()
# Out:
# Seattle, Washington, United States                     2885
# Shoreline, Washington, United States                      6
# West Seattle, Washington, Washington, United States       1
# Seattle, Wa, United States                                1
# West Seattle, Washington, United States                   1
# Ballard, Seattle, Washington, United States               1
# Ballard Seattle, Washington, United States                1
#  Seattle,  WA, United States                              1
# Name: neighbourhood, dtype: int64

# %%
boston_listings_clean['host_response_time'].value_counts()
# Out:
# within an hour        1575
# within a few hours     429
# within a day           255
# a few days or more      79
# Name: host_response_time, dtype: int64

# %%
seattle_listings_clean['host_response_time'].value_counts()
# Out:
# within an hour        2716
# within a few hours     661
# within a day           214
# a few days or more      68
# Name: host_response_time, dtype: int64

# %%
boston_listings_clean['host_response_time'].isnull().sum()
# Out:
# 699

# %%
#fill null host response time with mode
boston_listings_clean['host_response_time'].fillna('within an hour',inplace=True)
seattle_listings_clean['host_response_time'].fillna('within an hour',inplace=True)

# %%
boston_listings_clean['host_response_rate'].value_counts()
# Out:
# 100%    1562
# 97%      145
# 99%      107
# 90%       79
# 96%       55
# 93%       52
# 0%        44
# 85%       27
# 89%       26
# 60%       21
# 50%       19
# 80%       18
# 63%       17
# 92%       13
# 81%       13
# 95%       12
# 98%       11
# 91%       11
# 20%        8
# 94%        8
# 86%        8
# 68%        7
# 78%        7
# 70%        7
# 83%        7
# 11%        6
# 75%        5
# 88%        5
# 84%        5
# 67%        4
# 57%        4
# 40%        4
# 31%        3
# 30%        3
# 55%        2
# 43%        2
# 10%        2
# 25%        2
# 38%        2
# 76%        1
# 82%        1
# 33%        1
# 21%        1
# 17%        1
# Name: host_response_rate, dtype: int64

# %%
seattle_listings_clean['host_response_rate'].value_counts()
# Out:
# 100%    2771
# 90%      169
# 88%      142
# 97%       93
# 99%       59
# 96%       46
# 0%        45
# 50%       33
# 98%       32
# 91%       28
# 94%       24
# 80%       22
# 70%       21
# 87%       20
# 92%       19
# 93%       18
# 67%       15
# 95%       14
# 83%       11
# 60%        9
# 86%        8
# 57%        7
# 75%        7
# 73%        6
# 71%        6
# 33%        5
# 89%        4
# 40%        4
# 30%        3
# 36%        2
# 10%        2
# 74%        2
# 85%        2
# 24%        1
# 44%        1
# 20%        1
# 25%        1
# 43%        1
# 82%        1
# 78%        1
# 81%        1
# 38%        1
# 17%        1
# Name: host_response_rate, dtype: int64

# %%
boston_listings_clean['host_response_rate'] = boston_listings_clean['host_response_rate'].str.replace("%","")
seattle_listings_clean['host_response_rate'] = seattle_listings_clean['host_response_rate'].str.replace("%","")

# %%
boston_listings_clean['host_response_rate']=pd.to_numeric(boston_listings_clean['host_response_rate'])
seattle_listings_clean['host_response_rate']=pd.to_numeric(seattle_listings_clean['host_response_rate'])

# %%
fill_null_mode('host_response_rate')

# %%
seattle_listings_clean['host_response_rate'].value_counts()
# Out:
# 100.0    3206
# 90.0      169
# 88.0      142
# 97.0       93
# 99.0       59
# 96.0       46
# 0.0        45
# 50.0       33
# 98.0       32
# 91.0       28
# 94.0       24
# 80.0       22
# 70.0       21
# 87.0       20
# 92.0       19
# 93.0       18
# 67.0       15
# 95.0       14
# 83.0       11
# 60.0        9
# 86.0        8
# 57.0        7
# 75.0        7
# 71.0        6
# 73.0        6
# 33.0        5
# 89.0        4
# 40.0        4
# 30.0        3
# 74.0        2
# 10.0        2
# 36.0        2
# 85.0        2
# 20.0        1
# 44.0        1
# 43.0        1
# 38.0        1
# 25.0        1
# 81.0        1
# 78.0        1
# 82.0        1
# 17.0        1
# 24.0        1
# Name: host_response_rate, dtype: int64

# %%
boston_listings_clean['host_acceptance_rate'] = boston_listings_clean['host_acceptance_rate'].str.replace("%","")
seattle_listings_clean['host_acceptance_rate'] = seattle_listings_clean['host_acceptance_rate'].str.replace("%","")

# %%
boston_listings_clean['host_acceptance_rate']=pd.to_numeric(boston_listings_clean['host_acceptance_rate'])
seattle_listings_clean['host_acceptance_rate']=pd.to_numeric(seattle_listings_clean['host_acceptance_rate'])

# %%
fill_null_mean('host_acceptance_rate')

# %%
boston_listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3037 entries, 0 to 3042
# Data columns (total 71 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3037 non-null   int64
#  1   listing_url                                   3037 non-null   object
#  2   scrape_id                                     3037 non-null   int64
#  3   last_scraped                                  3037 non-null   object
#  4   name                                          3037 non-null   object
#  5   description                                   3004 non-null   object
#  6   neighborhood_overview                         2068 non-null   object
#  7   picture_url                                   3037 non-null   object
#  8   host_id                                       3037 non-null   int64
#  9   host_url                                      3037 non-null   object
#  10  host_name                                     3037 non-null   object
#  11  host_since                                    3037 non-null   object
#  12  host_location                                 3035 non-null   object
#  13  host_about                                    2043 non-null   object
#  14  host_response_time                            3037 non-null   object
#  15  host_response_rate                            3037 non-null   float64
#  16  host_acceptance_rate                          3037 non-null   float64
#  17  host_is_superhost                             3037 non-null   object
#  18  host_thumbnail_url                            3037 non-null   object
#  19  host_picture_url                              3037 non-null   object
#  20  host_neighbourhood                            2835 non-null   object
#  21  host_listings_count                           3037 non-null   int64
#  22  host_total_listings_count                     3037 non-null   int64
#  23  host_verifications                            3037 non-null   object
#  24  host_has_profile_pic                          3037 non-null   object
#  25  host_identity_verified                        3037 non-null   object
#  26  neighbourhood                                 2068 non-null   object
#  27  neighbourhood_cleansed                        3037 non-null   object
#  28  latitude                                      3037 non-null   float64
#  29  longitude                                     3037 non-null   float64
#  30  property_type                                 3037 non-null   object
#  31  room_type                                     3037 non-null   object
#  32  accommodates                                  3037 non-null   int64
#  33  bathrooms_text                                3034 non-null   object
#  34  bedrooms                                      2644 non-null   float64
#  35  beds                                          2960 non-null   float64
#  36  amenities                                     3037 non-null   object
#  37  price                                         3037 non-null   int64
#  38  minimum_nights                                3037 non-null   int64
#  39  maximum_nights                                3037 non-null   int64
#  40  minimum_minimum_nights                        3037 non-null   int64
#  41  maximum_minimum_nights                        3037 non-null   int64
#  42  minimum_maximum_nights                        3037 non-null   int64
#  43  maximum_maximum_nights                        3037 non-null   int64
#  44  minimum_nights_avg_ntm                        3037 non-null   float64
#  45  maximum_nights_avg_ntm                        3037 non-null   float64
#  46  has_availability                              3037 non-null   object
#  47  availability_30                               3037 non-null   int64
#  48  availability_60                               3037 non-null   int64
#  49  availability_90                               3037 non-null   int64
#  50  availability_365                              3037 non-null   int64
#  51  calendar_last_scraped                         3037 non-null   object
#  52  number_of_reviews                             3037 non-null   int64
#  53  number_of_reviews_ltm                         3037 non-null   int64
#  54  number_of_reviews_l30d                        3037 non-null   int64
#  55  first_review                                  3037 non-null   int64
#  56  last_review                                   3037 non-null   int64
#  57  review_scores_rating                          3037 non-null   float64
#  58  review_scores_accuracy                        3037 non-null   float64
#  59  review_scores_cleanliness                     3037 non-null   float64
#  60  review_scores_checkin                         3037 non-null   float64
#  61  review_scores_communication                   3037 non-null   float64
#  62  review_scores_location                        3037 non-null   float64
#  63  review_scores_value                           3037 non-null   float64
#  64  license                                       1688 non-null   object
#  65  instant_bookable                              3037 non-null   object
#  66  calculated_host_listings_count                3037 non-null   int64
#  67  calculated_host_listings_count_entire_homes   3037 non-null   int64
#  68  calculated_host_listings_count_private_rooms  3037 non-null   int64
#  69  calculated_host_listings_count_shared_rooms   3037 non-null   int64
#  70  reviews_per_month                             3037 non-null   float64
# dtypes: float64(16), int64(26), object(29)
# memory usage: 1.7+ MB

# %%
seattle_listings_clean['host_about']
# Out:
# 0       I welcome guests from all walks of life and ev...
# 1       I am a therapist/innkeeper.I know my city well...
# 2       I am a visual artist who is  the  director of ...
# 3       The Sweet Orange reflects my passion and zest ...
# 4       The Sweet Orange reflects my passion and zest ...
#                               ...
# 4091                                                  NaN
# 4092    Why take a chance picking & choosing between s...
# 4093                                                  NaN
# 4094    I'm living in Seattle as an architect, but am ...
# 4095                                                  NaN
# Name: host_about, Length: 4094, dtype: object

# %%
#count number of words of the text
boston_listings_clean['host_about'] = boston_listings_clean['host_about'].str.split().str.len()
seattle_listings_clean['host_about'] = seattle_listings_clean['host_about'].str.split().str.len()

# %%
boston_listings_clean[boston_listings_clean['host_about'].isnull()]
# Out:
#             id  ... reviews_per_month
# 4        10813  ...              0.18
# 5        10986  ...              0.03
# 40      611081  ...              1.17
# 67     1077105  ...              0.00
# 84     1551205  ...              0.45
# ...        ...  ...               ...
# 3036  50898660  ...              0.00
# 3037  50899267  ...              0.00
# 3038  50904278  ...              0.00
# 3040  50937751  ...              0.00
# 3042  50959720  ...              0.00
#
# [994 rows x 71 columns]

# %%
fill_null_zero('host_about')

# %%
#count number of words of the text
boston_listings_clean['description'] = boston_listings_clean['description'].str.split().str.len()
seattle_listings_clean['description'] = seattle_listings_clean['description'].str.split().str.len()

# %%
boston_listings_clean['description'] .isnull().sum()
# Out:
# 33

# %%
boston_listings_clean[boston_listings_clean['description'] .isnull()==True]
# Out:
#             id  ... reviews_per_month
# 1406  29860624  ...              0.00
# 1443  30964172  ...              0.00
# 1448  31140376  ...              0.11
# 1492  32366109  ...              0.00
# 1561  33487000  ...              0.09
# 1600  34771001  ...              0.09
# 1638  35579707  ...              0.12
# 1652  35807024  ...              0.00
# 1686  36439921  ...              0.24
# 1702  36687285  ...              0.13
# 1737  37749165  ...              0.00
# 1742  37840842  ...              0.00
# 1743  37840971  ...              0.00
# 1754  38127095  ...              0.00
# 1790  38388360  ...              0.00
# 1887  40258908  ...              0.00
# 1952  40988554  ...              0.15
# 1979  41614184  ...              0.13
# 1986  41745395  ...              0.00
# 2010  42065556  ...              2.47
# 2011  42065558  ...              7.58
# 2029  42307264  ...              0.00
# 2097  43023604  ...              0.00
# 2133  43610374  ...              0.00
# 2164  44014524  ...              0.00
# 2256  45354353  ...              0.00
# 2624  48378476  ...              0.00
# 2628  48403559  ...              0.00
# 2669  48694469  ...              0.00
# 2672  48716762  ...              0.57
# 2804  49491448  ...              0.00
# 2863  49941156  ...              0.00
# 2973  50573372  ...              0.00
#
# [33 rows x 71 columns]

# %%
#count number of words of the text columns
boston_listings_clean['name'] = boston_listings_clean['name'].str.split().str.len()
seattle_listings_clean['name'] = seattle_listings_clean['name'].str.split().str.len()

# %%
fill_null_zero('description')

# %%
boston_listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3037 entries, 0 to 3042
# Data columns (total 71 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3037 non-null   int64
#  1   listing_url                                   3037 non-null   object
#  2   scrape_id                                     3037 non-null   int64
#  3   last_scraped                                  3037 non-null   object
#  4   name                                          3037 non-null   int64
#  5   description                                   3037 non-null   float64
#  6   neighborhood_overview                         2068 non-null   object
#  7   picture_url                                   3037 non-null   object
#  8   host_id                                       3037 non-null   int64
#  9   host_url                                      3037 non-null   object
#  10  host_name                                     3037 non-null   object
#  11  host_since                                    3037 non-null   object
#  12  host_location                                 3035 non-null   object
#  13  host_about                                    3037 non-null   float64
#  14  host_response_time                            3037 non-null   object
#  15  host_response_rate                            3037 non-null   float64
#  16  host_acceptance_rate                          3037 non-null   float64
#  17  host_is_superhost                             3037 non-null   object
#  18  host_thumbnail_url                            3037 non-null   object
#  19  host_picture_url                              3037 non-null   object
#  20  host_neighbourhood                            2835 non-null   object
#  21  host_listings_count                           3037 non-null   int64
#  22  host_total_listings_count                     3037 non-null   int64
#  23  host_verifications                            3037 non-null   object
#  24  host_has_profile_pic                          3037 non-null   object
#  25  host_identity_verified                        3037 non-null   object
#  26  neighbourhood                                 2068 non-null   object
#  27  neighbourhood_cleansed                        3037 non-null   object
#  28  latitude                                      3037 non-null   float64
#  29  longitude                                     3037 non-null   float64
#  30  property_type                                 3037 non-null   object
#  31  room_type                                     3037 non-null   object
#  32  accommodates                                  3037 non-null   int64
#  33  bathrooms_text                                3034 non-null   object
#  34  bedrooms                                      2644 non-null   float64
#  35  beds                                          2960 non-null   float64
#  36  amenities                                     3037 non-null   object
#  37  price                                         3037 non-null   int64
#  38  minimum_nights                                3037 non-null   int64
#  39  maximum_nights                                3037 non-null   int64
#  40  minimum_minimum_nights                        3037 non-null   int64
#  41  maximum_minimum_nights                        3037 non-null   int64
#  42  minimum_maximum_nights                        3037 non-null   int64
#  43  maximum_maximum_nights                        3037 non-null   int64
#  44  minimum_nights_avg_ntm                        3037 non-null   float64
#  45  maximum_nights_avg_ntm                        3037 non-null   float64
#  46  has_availability                              3037 non-null   object
#  47  availability_30                               3037 non-null   int64
#  48  availability_60                               3037 non-null   int64
#  49  availability_90                               3037 non-null   int64
#  50  availability_365                              3037 non-null   int64
#  51  calendar_last_scraped                         3037 non-null   object
#  52  number_of_reviews                             3037 non-null   int64
#  53  number_of_reviews_ltm                         3037 non-null   int64
#  54  number_of_reviews_l30d                        3037 non-null   int64
#  55  first_review                                  3037 non-null   int64
#  56  last_review                                   3037 non-null   int64
#  57  review_scores_rating                          3037 non-null   float64
#  58  review_scores_accuracy                        3037 non-null   float64
#  59  review_scores_cleanliness                     3037 non-null   float64
#  60  review_scores_checkin                         3037 non-null   float64
#  61  review_scores_communication                   3037 non-null   float64
#  62  review_scores_location                        3037 non-null   float64
#  63  review_scores_value                           3037 non-null   float64
#  64  license                                       1688 non-null   object
#  65  instant_bookable                              3037 non-null   object
#  66  calculated_host_listings_count                3037 non-null   int64
#  67  calculated_host_listings_count_entire_homes   3037 non-null   int64
#  68  calculated_host_listings_count_private_rooms  3037 non-null   int64
#  69  calculated_host_listings_count_shared_rooms   3037 non-null   int64
#  70  reviews_per_month                             3037 non-null   float64
# dtypes: float64(18), int64(27), object(26)
# memory usage: 1.7+ MB

# %%
boston_listings_clean['neighborhood_overview'] = boston_listings_clean['neighborhood_overview'].str.split().str.len()
seattle_listings_clean['neighborhood_overview'] = seattle_listings_clean['neighborhood_overview'].str.split().str.len()

fill_null_zero('neighborhood_overview')

# %%
boston_listings_clean['bedrooms'].value_counts()
# Out:
# 1.0    1885
# 2.0     470
# 3.0     181
# 4.0      79
# 5.0      22
# 6.0       5
# 7.0       2
# Name: bedrooms, dtype: int64

# %%
boston_listings_clean['bathrooms_text'].value_counts()
# Out:
# 1 bath               1585
# 1 shared bath         512
# 2 baths               293
# 1 private bath        161
# 2 shared baths        161
# 1.5 baths             103
# 1.5 shared baths       89
# 2.5 baths              40
# 3 baths                28
# 2.5 shared baths       14
# 3.5 baths              13
# 3 shared baths         12
# 6 shared baths          7
# 0 shared baths          5
# 5 baths                 3
# 4.5 baths               2
# Half-bath               1
# Private half-bath       1
# 3.5 shared baths        1
# 4 baths                 1
# Shared half-bath        1
# 0 baths                 1
# Name: bathrooms_text, dtype: int64

# %%
boston_listings_clean['bedrooms'].value_counts()
# Out:
# 1.0    1885
# 2.0     470
# 3.0     181
# 4.0      79
# 5.0      22
# 6.0       5
# 7.0       2
# Name: bedrooms, dtype: int64

# %%
boston_listings_clean['beds'].value_counts()
# Out:
# 1.0     1722
# 2.0      673
# 3.0      251
# 0.0      103
# 4.0      102
# 5.0       52
# 6.0       24
# 7.0       12
# 9.0        7
# 8.0        6
# 10.0       2
# 12.0       2
# 11.0       2
# 16.0       1
# 18.0       1
# Name: beds, dtype: int64

# %%
fill_null_mode('beds')
fill_null_mode('bedrooms')

# %%
boston_listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3037 entries, 0 to 3042
# Data columns (total 71 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3037 non-null   int64
#  1   listing_url                                   3037 non-null   object
#  2   scrape_id                                     3037 non-null   int64
#  3   last_scraped                                  3037 non-null   object
#  4   name                                          3037 non-null   int64
#  5   description                                   3037 non-null   float64
#  6   neighborhood_overview                         3037 non-null   float64
#  7   picture_url                                   3037 non-null   object
#  8   host_id                                       3037 non-null   int64
#  9   host_url                                      3037 non-null   object
#  10  host_name                                     3037 non-null   object
#  11  host_since                                    3037 non-null   object
#  12  host_location                                 3035 non-null   object
#  13  host_about                                    3037 non-null   float64
#  14  host_response_time                            3037 non-null   object
#  15  host_response_rate                            3037 non-null   float64
#  16  host_acceptance_rate                          3037 non-null   float64
#  17  host_is_superhost                             3037 non-null   object
#  18  host_thumbnail_url                            3037 non-null   object
#  19  host_picture_url                              3037 non-null   object
#  20  host_neighbourhood                            2835 non-null   object
#  21  host_listings_count                           3037 non-null   int64
#  22  host_total_listings_count                     3037 non-null   int64
#  23  host_verifications                            3037 non-null   object
#  24  host_has_profile_pic                          3037 non-null   object
#  25  host_identity_verified                        3037 non-null   object
#  26  neighbourhood                                 2068 non-null   object
#  27  neighbourhood_cleansed                        3037 non-null   object
#  28  latitude                                      3037 non-null   float64
#  29  longitude                                     3037 non-null   float64
#  30  property_type                                 3037 non-null   object
#  31  room_type                                     3037 non-null   object
#  32  accommodates                                  3037 non-null   int64
#  33  bathrooms_text                                3034 non-null   object
#  34  bedrooms                                      3037 non-null   float64
#  35  beds                                          3037 non-null   float64
#  36  amenities                                     3037 non-null   object
#  37  price                                         3037 non-null   int64
#  38  minimum_nights                                3037 non-null   int64
#  39  maximum_nights                                3037 non-null   int64
#  40  minimum_minimum_nights                        3037 non-null   int64
#  41  maximum_minimum_nights                        3037 non-null   int64
#  42  minimum_maximum_nights                        3037 non-null   int64
#  43  maximum_maximum_nights                        3037 non-null   int64
#  44  minimum_nights_avg_ntm                        3037 non-null   float64
#  45  maximum_nights_avg_ntm                        3037 non-null   float64
#  46  has_availability                              3037 non-null   object
#  47  availability_30                               3037 non-null   int64
#  48  availability_60                               3037 non-null   int64
#  49  availability_90                               3037 non-null   int64
#  50  availability_365                              3037 non-null   int64
#  51  calendar_last_scraped                         3037 non-null   object
#  52  number_of_reviews                             3037 non-null   int64
#  53  number_of_reviews_ltm                         3037 non-null   int64
#  54  number_of_reviews_l30d                        3037 non-null   int64
#  55  first_review                                  3037 non-null   int64
#  56  last_review                                   3037 non-null   int64
#  57  review_scores_rating                          3037 non-null   float64
#  58  review_scores_accuracy                        3037 non-null   float64
#  59  review_scores_cleanliness                     3037 non-null   float64
#  60  review_scores_checkin                         3037 non-null   float64
#  61  review_scores_communication                   3037 non-null   float64
#  62  review_scores_location                        3037 non-null   float64
#  63  review_scores_value                           3037 non-null   float64
#  64  license                                       1688 non-null   object
#  65  instant_bookable                              3037 non-null   object
#  66  calculated_host_listings_count                3037 non-null   int64
#  67  calculated_host_listings_count_entire_homes   3037 non-null   int64
#  68  calculated_host_listings_count_private_rooms  3037 non-null   int64
#  69  calculated_host_listings_count_shared_rooms   3037 non-null   int64
#  70  reviews_per_month                             3037 non-null   float64
# dtypes: float64(19), int64(27), object(25)
# memory usage: 1.7+ MB

# %%
boston_listings_clean['bedrooms'] = boston_listings_clean['bedrooms'].astype(int)
seattle_listings_clean['bedrooms'] = seattle_listings_clean['bedrooms'].astype(int)

boston_listings_clean['beds'] = boston_listings_clean['beds'].astype(int)
seattle_listings_clean['beds'] = seattle_listings_clean['beds'].astype(int)

# %%
boston_listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3037 entries, 0 to 3042
# Data columns (total 71 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3037 non-null   int64
#  1   listing_url                                   3037 non-null   object
#  2   scrape_id                                     3037 non-null   int64
#  3   last_scraped                                  3037 non-null   object
#  4   name                                          3037 non-null   int64
#  5   description                                   3037 non-null   float64
#  6   neighborhood_overview                         3037 non-null   float64
#  7   picture_url                                   3037 non-null   object
#  8   host_id                                       3037 non-null   int64
#  9   host_url                                      3037 non-null   object
#  10  host_name                                     3037 non-null   object
#  11  host_since                                    3037 non-null   object
#  12  host_location                                 3035 non-null   object
#  13  host_about                                    3037 non-null   float64
#  14  host_response_time                            3037 non-null   object
#  15  host_response_rate                            3037 non-null   float64
#  16  host_acceptance_rate                          3037 non-null   float64
#  17  host_is_superhost                             3037 non-null   object
#  18  host_thumbnail_url                            3037 non-null   object
#  19  host_picture_url                              3037 non-null   object
#  20  host_neighbourhood                            2835 non-null   object
#  21  host_listings_count                           3037 non-null   int64
#  22  host_total_listings_count                     3037 non-null   int64
#  23  host_verifications                            3037 non-null   object
#  24  host_has_profile_pic                          3037 non-null   object
#  25  host_identity_verified                        3037 non-null   object
#  26  neighbourhood                                 2068 non-null   object
#  27  neighbourhood_cleansed                        3037 non-null   object
#  28  latitude                                      3037 non-null   float64
#  29  longitude                                     3037 non-null   float64
#  30  property_type                                 3037 non-null   object
#  31  room_type                                     3037 non-null   object
#  32  accommodates                                  3037 non-null   int64
#  33  bathrooms_text                                3034 non-null   object
#  34  bedrooms                                      3037 non-null   int64
#  35  beds                                          3037 non-null   int64
#  36  amenities                                     3037 non-null   object
#  37  price                                         3037 non-null   int64
#  38  minimum_nights                                3037 non-null   int64
#  39  maximum_nights                                3037 non-null   int64
#  40  minimum_minimum_nights                        3037 non-null   int64
#  41  maximum_minimum_nights                        3037 non-null   int64
#  42  minimum_maximum_nights                        3037 non-null   int64
#  43  maximum_maximum_nights                        3037 non-null   int64
#  44  minimum_nights_avg_ntm                        3037 non-null   float64
#  45  maximum_nights_avg_ntm                        3037 non-null   float64
#  46  has_availability                              3037 non-null   object
#  47  availability_30                               3037 non-null   int64
#  48  availability_60                               3037 non-null   int64
#  49  availability_90                               3037 non-null   int64
#  50  availability_365                              3037 non-null   int64
#  51  calendar_last_scraped                         3037 non-null   object
#  52  number_of_reviews                             3037 non-null   int64
#  53  number_of_reviews_ltm                         3037 non-null   int64
#  54  number_of_reviews_l30d                        3037 non-null   int64
#  55  first_review                                  3037 non-null   int64
#  56  last_review                                   3037 non-null   int64
#  57  review_scores_rating                          3037 non-null   float64
#  58  review_scores_accuracy                        3037 non-null   float64
#  59  review_scores_cleanliness                     3037 non-null   float64
#  60  review_scores_checkin                         3037 non-null   float64
#  61  review_scores_communication                   3037 non-null   float64
#  62  review_scores_location                        3037 non-null   float64
#  63  review_scores_value                           3037 non-null   float64
#  64  license                                       1688 non-null   object
#  65  instant_bookable                              3037 non-null   object
#  66  calculated_host_listings_count                3037 non-null   int64
#  67  calculated_host_listings_count_entire_homes   3037 non-null   int64
#  68  calculated_host_listings_count_private_rooms  3037 non-null   int64
#  69  calculated_host_listings_count_shared_rooms   3037 non-null   int64
#  70  reviews_per_month                             3037 non-null   float64
# dtypes: float64(17), int64(29), object(25)
# memory usage: 1.7+ MB

# %%
seattle_listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4094 entries, 0 to 4095
# Data columns (total 72 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4094 non-null   int64
#  1   listing_url                                   4094 non-null   object
#  2   scrape_id                                     4094 non-null   int64
#  3   last_scraped                                  4094 non-null   object
#  4   name                                          4094 non-null   int64
#  5   description                                   4094 non-null   float64
#  6   neighborhood_overview                         4094 non-null   float64
#  7   picture_url                                   4094 non-null   object
#  8   host_id                                       4094 non-null   int64
#  9   host_url                                      4094 non-null   object
#  10  host_name                                     4094 non-null   object
#  11  host_since                                    4094 non-null   object
#  12  host_location                                 4087 non-null   object
#  13  host_about                                    4094 non-null   float64
#  14  host_response_time                            4094 non-null   object
#  15  host_response_rate                            4094 non-null   float64
#  16  host_acceptance_rate                          4094 non-null   float64
#  17  host_is_superhost                             4094 non-null   object
#  18  host_thumbnail_url                            4094 non-null   object
#  19  host_picture_url                              4094 non-null   object
#  20  host_neighbourhood                            3778 non-null   object
#  21  host_listings_count                           4094 non-null   int64
#  22  host_total_listings_count                     4094 non-null   int64
#  23  host_verifications                            4094 non-null   object
#  24  host_has_profile_pic                          4094 non-null   object
#  25  host_identity_verified                        4094 non-null   object
#  26  neighbourhood                                 2897 non-null   object
#  27  neighbourhood_cleansed                        4094 non-null   object
#  28  neighbourhood_group_cleansed                  4094 non-null   object
#  29  latitude                                      4094 non-null   float64
#  30  longitude                                     4094 non-null   float64
#  31  property_type                                 4094 non-null   object
#  32  room_type                                     4094 non-null   object
#  33  accommodates                                  4094 non-null   int64
#  34  bathrooms_text                                4092 non-null   object
#  35  bedrooms                                      4094 non-null   int64
#  36  beds                                          4094 non-null   int64
#  37  amenities                                     4094 non-null   object
#  38  price                                         4094 non-null   int64
#  39  minimum_nights                                4094 non-null   int64
#  40  maximum_nights                                4094 non-null   int64
#  41  minimum_minimum_nights                        4094 non-null   int64
#  42  maximum_minimum_nights                        4094 non-null   int64
#  43  minimum_maximum_nights                        4094 non-null   int64
#  44  maximum_maximum_nights                        4094 non-null   int64
#  45  minimum_nights_avg_ntm                        4094 non-null   float64
#  46  maximum_nights_avg_ntm                        4094 non-null   float64
#  47  has_availability                              4094 non-null   object
#  48  availability_30                               4094 non-null   int64
#  49  availability_60                               4094 non-null   int64
#  50  availability_90                               4094 non-null   int64
#  51  availability_365                              4094 non-null   int64
#  52  calendar_last_scraped                         4094 non-null   object
#  53  number_of_reviews                             4094 non-null   int64
#  54  number_of_reviews_ltm                         4094 non-null   int64
#  55  number_of_reviews_l30d                        4094 non-null   int64
#  56  first_review                                  4094 non-null   int64
#  57  last_review                                   4094 non-null   int64
#  58  review_scores_rating                          4094 non-null   float64
#  59  review_scores_accuracy                        4094 non-null   float64
#  60  review_scores_cleanliness                     4094 non-null   float64
#  61  review_scores_checkin                         4094 non-null   float64
#  62  review_scores_communication                   4094 non-null   float64
#  63  review_scores_location                        4094 non-null   float64
#  64  review_scores_value                           4094 non-null   float64
#  65  license                                       2977 non-null   object
#  66  instant_bookable                              4094 non-null   object
#  67  calculated_host_listings_count                4094 non-null   int64
#  68  calculated_host_listings_count_entire_homes   4094 non-null   int64
#  69  calculated_host_listings_count_private_rooms  4094 non-null   int64
#  70  calculated_host_listings_count_shared_rooms   4094 non-null   int64
#  71  reviews_per_month                             4094 non-null   float64
# dtypes: float64(17), int64(29), object(26)
# memory usage: 2.3+ MB

# %%
boston_listings_clean = boston_listings_clean.drop( ['host_neighbourhood','host_location'],axis=1)
seattle_listings_clean = seattle_listings_clean.drop( ['host_neighbourhood','host_location'],axis=1)

# %%
boston_listings_clean['license'] = boston_listings_clean['license'].apply(lambda x: 'No' if pd.isnull(x) else 'Yes')
seattle_listings_clean['license'] = seattle_listings_clean['license'].apply(lambda x: 'No' if pd.isnull(x) else 'Yes')

# %%
boston_listings_clean['license'].value_counts()
# Out:
# Yes    1688
# No     1349
# Name: license, dtype: int64

# %%
seattle_listings_clean['license'].value_counts()
# Out:
# Yes    2977
# No     1117
# Name: license, dtype: int64

# %%
#drop unnecessary varaibles for modelling
boston_listings_clean = boston_listings_clean.drop(['last_scraped','id','scrape_id','listing_url','picture_url','host_id','host_url','host_name','calendar_last_scraped','bathrooms_text','host_thumbnail_url','host_picture_url','amenities','host_since'],axis=1)
seattle_listings_clean = seattle_listings_clean.drop(['last_scraped','id','scrape_id','listing_url','picture_url','host_id','host_url','host_name','calendar_last_scraped','bathrooms_text','host_thumbnail_url','host_picture_url','amenities','host_since'],axis=1)

# %%
boston_listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3037 entries, 0 to 3042
# Data columns (total 55 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   name                                          3037 non-null   int64
#  1   description                                   3037 non-null   float64
#  2   neighborhood_overview                         3037 non-null   float64
#  3   host_about                                    3037 non-null   float64
#  4   host_response_time                            3037 non-null   object
#  5   host_response_rate                            3037 non-null   float64
#  6   host_acceptance_rate                          3037 non-null   float64
#  7   host_is_superhost                             3037 non-null   object
#  8   host_listings_count                           3037 non-null   int64
#  9   host_total_listings_count                     3037 non-null   int64
#  10  host_verifications                            3037 non-null   object
#  11  host_has_profile_pic                          3037 non-null   object
#  12  host_identity_verified                        3037 non-null   object
#  13  neighbourhood                                 2068 non-null   object
#  14  neighbourhood_cleansed                        3037 non-null   object
#  15  latitude                                      3037 non-null   float64
#  16  longitude                                     3037 non-null   float64
#  17  property_type                                 3037 non-null   object
#  18  room_type                                     3037 non-null   object
#  19  accommodates                                  3037 non-null   int64
#  20  bedrooms                                      3037 non-null   int64
#  21  beds                                          3037 non-null   int64
#  22  price                                         3037 non-null   int64
#  23  minimum_nights                                3037 non-null   int64
#  24  maximum_nights                                3037 non-null   int64
#  25  minimum_minimum_nights                        3037 non-null   int64
#  26  maximum_minimum_nights                        3037 non-null   int64
#  27  minimum_maximum_nights                        3037 non-null   int64
#  28  maximum_maximum_nights                        3037 non-null   int64
#  29  minimum_nights_avg_ntm                        3037 non-null   float64
#  30  maximum_nights_avg_ntm                        3037 non-null   float64
#  31  has_availability                              3037 non-null   object
#  32  availability_30                               3037 non-null   int64
#  33  availability_60                               3037 non-null   int64
#  34  availability_90                               3037 non-null   int64
#  35  availability_365                              3037 non-null   int64
#  36  number_of_reviews                             3037 non-null   int64
#  37  number_of_reviews_ltm                         3037 non-null   int64
#  38  number_of_reviews_l30d                        3037 non-null   int64
#  39  first_review                                  3037 non-null   int64
#  40  last_review                                   3037 non-null   int64
#  41  review_scores_rating                          3037 non-null   float64
#  42  review_scores_accuracy                        3037 non-null   float64
#  43  review_scores_cleanliness                     3037 non-null   float64
#  44  review_scores_checkin                         3037 non-null   float64
#  45  review_scores_communication                   3037 non-null   float64
#  46  review_scores_location                        3037 non-null   float64
#  47  review_scores_value                           3037 non-null   float64
#  48  license                                       3037 non-null   object
#  49  instant_bookable                              3037 non-null   object
#  50  calculated_host_listings_count                3037 non-null   int64
#  51  calculated_host_listings_count_entire_homes   3037 non-null   int64
#  52  calculated_host_listings_count_private_rooms  3037 non-null   int64
#  53  calculated_host_listings_count_shared_rooms   3037 non-null   int64
#  54  reviews_per_month                             3037 non-null   float64
# dtypes: float64(17), int64(26), object(12)
# memory usage: 1.3+ MB

# %%
seattle_listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4094 entries, 0 to 4095
# Data columns (total 56 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   name                                          4094 non-null   int64
#  1   description                                   4094 non-null   float64
#  2   neighborhood_overview                         4094 non-null   float64
#  3   host_about                                    4094 non-null   float64
#  4   host_response_time                            4094 non-null   object
#  5   host_response_rate                            4094 non-null   float64
#  6   host_acceptance_rate                          4094 non-null   float64
#  7   host_is_superhost                             4094 non-null   object
#  8   host_listings_count                           4094 non-null   int64
#  9   host_total_listings_count                     4094 non-null   int64
#  10  host_verifications                            4094 non-null   object
#  11  host_has_profile_pic                          4094 non-null   object
#  12  host_identity_verified                        4094 non-null   object
#  13  neighbourhood                                 2897 non-null   object
#  14  neighbourhood_cleansed                        4094 non-null   object
#  15  neighbourhood_group_cleansed                  4094 non-null   object
#  16  latitude                                      4094 non-null   float64
#  17  longitude                                     4094 non-null   float64
#  18  property_type                                 4094 non-null   object
#  19  room_type                                     4094 non-null   object
#  20  accommodates                                  4094 non-null   int64
#  21  bedrooms                                      4094 non-null   int64
#  22  beds                                          4094 non-null   int64
#  23  price                                         4094 non-null   int64
#  24  minimum_nights                                4094 non-null   int64
#  25  maximum_nights                                4094 non-null   int64
#  26  minimum_minimum_nights                        4094 non-null   int64
#  27  maximum_minimum_nights                        4094 non-null   int64
#  28  minimum_maximum_nights                        4094 non-null   int64
#  29  maximum_maximum_nights                        4094 non-null   int64
#  30  minimum_nights_avg_ntm                        4094 non-null   float64
#  31  maximum_nights_avg_ntm                        4094 non-null   float64
#  32  has_availability                              4094 non-null   object
#  33  availability_30                               4094 non-null   int64
#  34  availability_60                               4094 non-null   int64
#  35  availability_90                               4094 non-null   int64
#  36  availability_365                              4094 non-null   int64
#  37  number_of_reviews                             4094 non-null   int64
#  38  number_of_reviews_ltm                         4094 non-null   int64
#  39  number_of_reviews_l30d                        4094 non-null   int64
#  40  first_review                                  4094 non-null   int64
#  41  last_review                                   4094 non-null   int64
#  42  review_scores_rating                          4094 non-null   float64
#  43  review_scores_accuracy                        4094 non-null   float64
#  44  review_scores_cleanliness                     4094 non-null   float64
#  45  review_scores_checkin                         4094 non-null   float64
#  46  review_scores_communication                   4094 non-null   float64
#  47  review_scores_location                        4094 non-null   float64
#  48  review_scores_value                           4094 non-null   float64
#  49  license                                       4094 non-null   object
#  50  instant_bookable                              4094 non-null   object
#  51  calculated_host_listings_count                4094 non-null   int64
#  52  calculated_host_listings_count_entire_homes   4094 non-null   int64
#  53  calculated_host_listings_count_private_rooms  4094 non-null   int64
#  54  calculated_host_listings_count_shared_rooms   4094 non-null   int64
#  55  reviews_per_month                             4094 non-null   float64
# dtypes: float64(17), int64(26), object(13)
# memory usage: 1.8+ MB

# %% [markdown]
# ##(III b) Dealing with Categorical variables

# %%
def create_dummy_df(df, cat_cols, dummy_na):
   
    for col in  cat_cols:
        try:
            # for each cat add dummy var, drop original column
            df = pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_', drop_first=True, dummy_na=dummy_na)], axis=1)
        except:
            continue
    return df

# %%
df_boston  = boston_listings_clean
df_seattle  = seattle_listings_clean

# %%
cat_df = df_boston.select_dtypes(include=['object']).copy()
cat_cols_lst = cat_df.columns


df_boston_new = create_dummy_df(df_boston, cat_cols_lst, dummy_na=False) #Use your newly created function


print(df_boston_new .shape)
# Out:
# (3037, 297)

# %%
cat_df = df_seattle.select_dtypes(include=['object']).copy()
cat_cols_lst = cat_df.columns


df_seattle_new = create_dummy_df(df_seattle, cat_cols_lst, dummy_na=False) #Use your newly created function


print(df_seattle_new.shape)
# Out:
# (4094, 408)

# %%
df_boston_new.head()
# Out:
#    name  description  ...  license_Yes  instant_bookable_t
# 0     3        165.0  ...            0                   0
# 1     6        160.0  ...            1                   0
# 2     4        151.0  ...            1                   0
# 3     5        148.0  ...            0                   0
# 4     9        155.0  ...            0                   0
#
# [5 rows x 297 columns]

# %%
df_seattle_new.head()
# Out:
#    name  description  ...  license_Yes  instant_bookable_t
# 0    10        160.0  ...            1                   0
# 1     5        161.0  ...            1                   0
# 2     6        170.0  ...            1                   0
# 3     5        172.0  ...            1                   0
# 4     5        167.0  ...            1                   0
#
# [5 rows x 408 columns]

# %% [markdown]
# # (IV)Data model

# %%
from sklearn.preprocessing import StandardScaler

scale= StandardScaler()
test_size=0.3
rand_state=42



#Split into explanatory and response variables
X = df_boston_new.drop(['price'], axis=1)
y = df_boston_new['price']

# standardize variables
X_scaled = scale.fit_transform(X)
  


#Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=test_size, random_state=rand_state)

lm_model = LinearRegression(normalize=True) # Instantiate
lm_model.fit(X_train, y_train) #Fit

#Predict using your model
y_test_preds = lm_model.predict(X_test)
y_train_preds = lm_model.predict(X_train)

#Score using your model
test_score = r2_score(y_test, y_test_preds)
train_score = r2_score(y_train, y_train_preds)

print("The rsquared on the training data was {}.  The rsquared on the test data was {}.".format(train_score, test_score))


from sklearn import metrics
  

# The mean squared error
MSE = metrics.mean_squared_error(y_test,y_test_preds)
print("The MSE on the testing data was {}.".format(MSE))
# Out:
# The rsquared on the training data was -8.585928294034251e+20.  The rsquared on the test data was -1.6240327914426802e+56.
# The MSE on the testing data was 3.600484840405648e+60.

# %%
from sklearn.preprocessing import StandardScaler

scale= StandardScaler()
test_size=0.3
rand_state=42



#Split into explanatory and response variables
X = df_seattle_new.drop(['price'], axis=1)
y = df_seattle_new['price']

# standardize variables
X_scaled = scale.fit_transform(X)
  


#Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=test_size, random_state=rand_state)

lm_model = LinearRegression(normalize=True) # Instantiate
lm_model.fit(X_train, y_train) #Fit

#Predict using your model
y_test_preds = lm_model.predict(X_test)
y_train_preds = lm_model.predict(X_train)

#Score using your model
test_score = r2_score(y_test, y_test_preds)
train_score = r2_score(y_train, y_train_preds)



print("The rsquared on the training data was {}.  The rsquared on the test data was {}.".format(train_score, test_score))

from sklearn import metrics
  

# The mean squared error
MSE = metrics.mean_squared_error(y_test,y_test_preds)
print("The MSE on the testing data was {}.".format(MSE))
# Out:
# The rsquared on the training data was -9.476121994626245e+18.  The rsquared on the test data was -1.8089419973009374e+54.
# The MSE on the testing data was 2.7851011749299284e+58.
